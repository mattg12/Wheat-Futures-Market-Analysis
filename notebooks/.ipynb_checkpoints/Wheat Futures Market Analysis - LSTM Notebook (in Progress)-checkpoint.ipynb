# %% [markdown]
# # Capstone Project: Wheat Market Analysis
# ## LSTM Notebook
#
# ### Matthew Garton - General Assembly DSI-Boston
#
# **Purpose:** The purpose of this notebook is to try a neural network approach to recognizing patterns and predicting Wheat Futures Price data. I will attempt to build a LSTM model.
#
# **Context**: The ultimate goal of my project is to develop a trading strategy for commodity futures, which will include both prediction modeling to identify price patterns and trading opportunities as well as a rules-based algorithm to make trading decisions and manage risk.

# %%
import numpy as np, pandas as pd
import matplotlib.pyplot as plt

import math

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import LSTM

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.cross_validation import train_test_split

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
wheat = pd.read_csv('../data/wheat_final_modeling.csv', index_col='Date', parse_dates=True)

# %% [markdown]
# ## Data Preparation
#
# To prepare the data for LSTM modeling, I first create windows so that I can use multiple steps of historical data to predict the next data point. The window size is a hyperparameter which can be tuned over to improve model performance.
#
# Citation: GA Global Instructor David Yerrington provided starter code for window creation and model set up, which I have expanded upon.

# %%
def create_window(df, window_size = 1):    
    '''Return a dataframe with columns for each step in the window'''
    
    copy = df.copy()
    
    # for each row in the dataframe, add 'window size' columns,
    # each one representing the subsequent period's observation
    for i in range(window_size):
        df = pd.concat([df, copy.shift(-(i + 1))], 
                            axis = 1)
        
    df.dropna(axis=0, inplace=True)
    
    return df

# %% [markdown]
# There are a number of hyperparameters which can be tuned over in this framework. As an area for further refinement, I'd like to gridsearch over them to find the best possible model. For now, I'll instantiate all as variables in the cell below, and pass them as arguments into the model funtions. This will make it easier for me to manually tweak and tune the model.

# %%
# Model Parameters
window_size = 7
units = 25
activation = 'relu'
dropout = 0.2
epochs = 500
batch_size = 50
validation = 0.3

# %%
# Create dataset
wheat_window = create_window(wheat['2013':'2017']['Settle'], window_size = window_size)

# Create holdout set
test_window = create_window(wheat['2018'], window_size = window_size)

# X, y split - X is columns up to window size, y is the final observation in the window
X = wheat_window.iloc[:, 0:window_size]
y = wheat_window.iloc[:, window_size]

# %%
# Reshape data to fit in the model
X = np.reshape(X.values, (X.shape[0], 1, X.shape[1]))

# %%
# Instantiate and fit the LSTM network
model = Sequential()

model.add(LSTM(input_shape=(X.shape[1], X.shape[2]), units=25, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_logarithmic_error', optimizer='adam')
history = model.fit(x=X, y=y.values, epochs=100, batch_size=80, verbose=1, validation_split=0.3)
# Out:
# Train on 1017 samples, validate on 437 samples
# Epoch 1/100
# 1017/1017 [==============================] - 1s 745us/step - loss: 31.2772 - val_loss: 37.6360
# Epoch 2/100
# 1017/1017 [==============================] - 0s 34us/step - loss: 18.0236 - val_loss: 4.8314
# Epoch 3/100
# 1017/1017 [==============================] - 0s 37us/step - loss: 9.4582 - val_loss: 2.4344
# Epoch 4/100
# 1017/1017 [==============================] - 0s 39us/step - loss: 4.1489 - val_loss: 1.5682
# Epoch 5/100
# 1017/1017 [==============================] - 0s 70us/step - loss: 0.2537 - val_loss: 0.0034
# Epoch 83/100
# 1017/1017 [==============================] - 0s 62us/step - loss: 0.2481 - val_loss: 0.0032
# Epoch 84/100
# 1017/1017 [==============================] - 0s 61us/step - loss: 0.5531 - val_loss: 0.0029
# Epoch 85/100
# 1017/1017 [==============================] - 0s 100us/step - loss: 0.2794 - val_loss: 0.0027
# Epoch 86/100
# 1017/1017 [==============================] - 0s 97us/step - loss: 0.3326 - val_loss: 0.0024
# Epoch 87/100
# 1017/1017 [==============================] - 0s 94us/step - loss: 0.5176 - val_loss: 0.0022
# Epoch 88/100
# 1017/1017 [==============================] - 0s 96us/step - loss: 0.4612 - val_loss: 0.0020
# Epoch 89/100
# 1017/1017 [==============================] - 0s 98us/step - loss: 0.3150 - val_loss: 0.0018
# Epoch 90/100
# 1017/1017 [==============================] - 0s 94us/step - loss: 0.4469 - val_loss: 0.0017
# Epoch 91/100
# 1017/1017 [==============================] - 0s 100us/step - loss: 0.3515 - val_loss: 0.0015
# Epoch 92/100
# 1017/1017 [==============================] - 0s 98us/step - loss: 0.2883 - val_loss: 0.0014
# Epoch 93/100
# 1017/1017 [==============================] - 0s 140us/step - loss: 0.3036 - val_loss: 0.0013
# Epoch 94/100
# 1017/1017 [==============================] - 0s 133us/step - loss: 0.4250 - val_loss: 0.0012
# Epoch 95/100
# 1017/1017 [==============================] - 0s 96us/step - loss: 0.3454 - val_loss: 0.0011
# Epoch 96/100
# 1017/1017 [==============================] - 0s 102us/step - loss: 0.2794 - val_loss: 0.0011
# Epoch 97/100
# 1017/1017 [==============================] - 0s 102us/step - loss: 0.3733 - val_loss: 0.0010
# Epoch 98/100
# 1017/1017 [==============================] - 0s 114us/step - loss: 0.3084 - val_loss: 0.0010
# Epoch 99/100
# 1017/1017 [==============================] - 0s 146us/step - loss: 0.1933 - val_loss: 9.6963e-04
# Epoch 100/100
# 1017/1017 [==============================] - 0s 102us/step - loss: 0.5275 - val_loss: 9.4261e-04

# %%
# Save Training Loss and Validation Loss in a df
metrics = pd.DataFrame(history.history, columns=['val_loss', 'loss'])

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
fig.suptitle("LSTM: Timestep $-{}$, Dropout: {}, units: {}, epochs: {}, validation: {}, loss: RMSLogE".format(
    window_size, dropout, units, epochs, validation))

# Generate Predictions
y_hat = model.predict(X)

results = pd.DataFrame(list(zip(y_hat, X)), columns=["y_hat", "var"])
results['y_hat'] = results['y_hat'].map(lambda y_hat: y_hat[0])
results['var'] = results['var'] = results['var'].map(lambda var: var[0][0])
results.plot(ax=ax[1])
metrics.plot(ax=ax[0]);

# %% [markdown]
# ## Observations
#
# The model seems promising so far, although I am concerned about overfitting. Additionally, I think predicting forward one point is of limited value, so I need to work on predicting further out.
